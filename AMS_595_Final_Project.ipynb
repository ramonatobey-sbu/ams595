# %% [markdown]
# <a href="https://colab.research.google.com/github/ramonatobey-sbu/ams595/blob/main/AMS_595_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AMS 595 Final Project by
# Annie, Chanel and Ramona

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('MVC.csv')
#display(df)

# %%
filtered_data = pd.read_csv('MVC.csv', usecols=['CRASH DATE', 'LATITUDE', 'LONGITUDE', 'ON STREET NAME', 'CROSS STREET NAME', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2'])

# %%
# Graphing Crash Locations by Latitude and Longitude

# remove all latitude and longitude
filtered_data_cleaned = filtered_data[(filtered_data['LATITUDE'] != 0) | (filtered_data['LONGITUDE'] != 0)]


plt.figure(figsize=(10, 8))
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=filtered_data_cleaned, alpha=0.5, hue='NUMBER OF PERSONS INJURED', palette='dark')
plt.title('Crash Locations by Latitude and Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# take out columns where the street names are empty
filtered_data_cross_streets = filtered_data[(filtered_data['ON STREET NAME'] != '') | (filtered_data['CROSS STREET NAME'] != '')]

# Clean street names
filtered_data['ON STREET NAME'] = filtered_data['ON STREET NAME'].astype(str).str.strip().str.upper()
filtered_data['CROSS STREET NAME'] = filtered_data['CROSS STREET NAME'].astype(str).str.strip().str.upper()

# add a column for intersections to the filtered data
filtered_data['INTERSECTION'] = filtered_data.apply(lambda row: ' & '.join(sorted([row['ON STREET NAME'], row['CROSS STREET NAME']])) if row['CROSS STREET NAME'] and row['CROSS STREET NAME'] != 'NAN' else row['ON STREET NAME'], axis=1)

# count the number of crashes at each intersection pair
intersection_counts = filtered_data['INTERSECTION'].value_counts()

# print out the top 20 intersections for number of crashes
top_20_intersections = intersection_counts.head(20)
print("Top 20 Intersections with Most Crashes:")
print(top_20_intersections)
# Out:
# Top 20 Intersections with Most Crashes:
# INTERSECTION
# MAJOR DEEGAN EXPRESSWAY & WEST FORDHAM ROAD    183
# BRONX RIVER PARKWAY & EAST GUN HILL ROAD        86
# EAST 149 STREET & GRAND CONCOURSE               83
# EAST GUN HILL ROAD & WEBSTER AVENUE             80
# BRUCKNER BOULEVARD & SAINT ANNS AVENUE          80
# EAST 135 STREET & WILLIS AVENUE                 77
# BRUCKNER BOULEVARD & HUNTS POINT AVENUE         73
# EAST 138 STREET & EXTERIOR STREET               72
# EAST 149 STREET & MORRIS AVENUE                 69
# BROWN PLACE & BRUCKNER BOULEVARD                67
# EAST FORDHAM ROAD & SOUTHERN BOULEVARD          66
# EAST 233 STREET & WEBSTER AVENUE                66
# EAST 161 STREET & MORRIS AVENUE                 61
# BRUCKNER BOULEVARD & EAST 141 STREET            61
# EAST FORDHAM ROAD & WEBSTER AVENUE              60
# BRUCKNER BOULEVARD & EAST 149 STREET            60
# EAST 161 STREET & GRAND CONCOURSE               59
# ...

# %%
# Graph top 5 intersections and their crash type in different colors

# FIRST INTERSECTION: MAJOR DEEGAN EXPRESSWAY & WEST FORDHAM ROAD
# isolating the data for the first intersection
intersection1 = filtered_data[filtered_data['INTERSECTION'] == 'MAJOR DEEGAN EXPRESSWAY & WEST FORDHAM ROAD']
intersection1_factor_counts = intersection1['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection1_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection1_factor_counts.index, y=intersection1_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'MAJOR DEEGAN EXPRESSWAY & WEST FORDHAM ROAD'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# SECOND INTERSECTION: BRONX RIVER PARKWAY & EAST GUN HILL ROAD
# isolating the data for the second intersection
intersection2 = filtered_data[filtered_data['INTERSECTION'] == 'BRONX RIVER PARKWAY & EAST GUN HILL ROAD']
intersection2_factor_counts = intersection2['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection2_factor_counts.index, y=intersection2_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'BRONX RIVER PARKWAY & EAST GUN HILL ROAD'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# THIRD INTERSECTION: EAST 149 STREET & GRAND CONCOURSE
# isolating the data for the second intersection
intersection3 = filtered_data[filtered_data['INTERSECTION'] == 'EAST 149 STREET & GRAND CONCOURSE']
intersection3_factor_counts = intersection3['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection3_factor_counts.index, y=intersection3_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'EAST 149 STREET & GRAND CONCOURSE'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# FOURTH INTERSECTION: EAST GUN HILL ROAD & WEBSTER AVENUE
# isolating the data for the second intersection
intersection4 = filtered_data[filtered_data['INTERSECTION'] == 'EAST GUN HILL ROAD & WEBSTER AVENUE']
intersection4_factor_counts = intersection4['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection4_factor_counts.index, y=intersection4_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'EAST GUN HILL ROAD & WEBSTER AVENUE'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# FIFTH INTERSECTION: BRUCKNER BOULEVARD & SAINT ANNS AVENUE
# isolating the data for the second intersection
intersection5 = filtered_data[filtered_data['INTERSECTION'] == 'BRUCKNER BOULEVARD & SAINT ANNS AVENUE']
intersection5_factor_counts = intersection5['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection5_factor_counts.index, y=intersection5_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'BRUCKNER BOULEVARD & SAINT ANNS AVENUE'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# SIXTH INTERSECTION: EAST 135 STREET & WILLIS AVENUE
# isolating the data for the second intersection
intersection6 = filtered_data[filtered_data['INTERSECTION'] == 'EAST 135 STREET & WILLIS AVENUE']
intersection6_factor_counts = intersection6['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection6_factor_counts.index, y=intersection6_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'EAST 135 STREET & WILLIS AVENUE'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# SEVENTH INTERSECTION: BRUCKNER BOULEVARD & HUNTS POINT AVENUE
# isolating the data for the second intersection
intersection7 = filtered_data[filtered_data['INTERSECTION'] == 'BRUCKNER BOULEVARD & HUNTS POINT AVENUE']
intersection7_factor_counts = intersection7['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection7_factor_counts.index, y=intersection7_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'BRUCKNER BOULEVARD & HUNTS POINT AVENUE'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# EIGHTH INTERSECTION: EAST 138 STREET & EXTERIOR STREET
# isolating the data for the second intersection
intersection8 = filtered_data[filtered_data['INTERSECTION'] == 'EAST 138 STREET & EXTERIOR STREET']
intersection8_factor_counts = intersection8['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection8_factor_counts.index, y=intersection8_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'EAST 138 STREET & EXTERIOR STREET'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# NINTH INTERSECTION: EAST 149 STREET & MORRIS AVENUE
# isolating the data for the second intersection
intersection9 = filtered_data[filtered_data['INTERSECTION'] == 'EAST 149 STREET & MORRIS AVENUE']
intersection9_factor_counts = intersection9['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection9_factor_counts.index, y=intersection9_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'EAST 149 STREET & MORRIS AVENUE'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# TENTH INTERSECTION: BROWN PLACE & BRUCKNER BOULEVARD
# isolating the data for the second intersection
intersection10 = filtered_data[filtered_data['INTERSECTION'] == 'BROWN PLACE & BRUCKNER BOULEVARD']
intersection10_factor_counts = intersection10['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()

# make a bar graph out of intersection2_factor_counts
plt.figure(figsize=(12, 8))
sns.barplot(x=intersection10_factor_counts.index, y=intersection10_factor_counts.values)
plt.title(f'Contributing Factors for Crashes at {'BROWN PLACE & BRUCKNER BOULEVARD'}')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
#WRITING A LIST OF THE FACTORS

factorList = []
for factorTest in filtered_data['CONTRIBUTING FACTOR VEHICLE 1']:
  factorTest = factorTest.lower()
  if factorTest not in factorList:
    factorList.append(factorTest)

print(factorList)
# Out:
# ['driver inattention/distraction', 'aggressive driving/road rage', 'unsafe lane changing', 'failure to yield right-of-way', 'backing unsafely', 'view obstructed/limited', 'alcohol involvement', 'unsafe speed', 'driver inexperience', 'other vehicular', 'following too closely', 'passing too closely', 'traffic control disregarded', 'turning improperly', 'oversized vehicle', 'pedestrian/bicyclist/other pedestrian error/confusion', 'reaction to uninvolved vehicle', 'passing or lane usage improper', 'pavement slippery', 'failure to keep right', 'traffic control device improper/non-working', 'obstruction/debris', 'texting', 'accelerator defective', 'passenger distraction', 'tinted windows', 'outside car distraction', 'glare', 'driverless/runaway vehicle', 'steering failure', 'brakes defective', 'tire failure/inadequate', 'drugs (illegal)', 'fell asleep', 'listening/using headphones', 'using on board navigation device', 'headlights defective', 'vehicle vandalism', 'lane marking improper/inad
# ...

# %%
#displaying the list of contributing factors

factor_countsV1 = filtered_data['CONTRIBUTING FACTOR VEHICLE 1'].str.lower().value_counts()
display(factor_countsV1)
factor_countsV2 = filtered_data['CONTRIBUTING FACTOR VEHICLE 2'].str.lower().value_counts()
display(factor_countsV2)
# Out:
# CONTRIBUTING FACTOR VEHICLE 1
# driver inattention/distraction                           6888
# other vehicular                                          4497
# failure to yield right-of-way                            1216
# traffic control disregarded                               701
# turning improperly                                        653
# passing or lane usage improper                            570
# backing unsafely                                          561
# driver inexperience                                       541
# unsafe speed                                              528
# following too closely                                     509
# passing too closely                                       492
# view obstructed/limited                                   472
# pavement slippery                                         398
# fatigued/drowsy                                           380
# unsafe lane changing                                      365
# ...

# %% [markdown]
# Now that we have this information about contributing factors, we can compare it with location data to see if some crash types are clusted in certain areas.

# %%
# Filter the data for crashes where 'CONTRIBUTING FACTOR VEHICLE 1' is 'traffic control disregarded'
tcd_crashes = filtered_data[filtered_data['CONTRIBUTING FACTOR VEHICLE 1'].str.lower() == 'traffic control disregarded']

# Plot these specific crashes
plt.figure(figsize=(10, 8))
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=tcd_crashes, alpha=0.5, hue='NUMBER OF PERSONS INJURED', palette='RdBu')
plt.title('Crash Locations with "Traffic Control Disregarded" Contributing Factor')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

#unused code

#now, I want to make a different plot of tcd_crashes vs time to see if anything happens over the years
#epoch_start = pd.to_datetime('1970-01-01')
#filtered_data['CRASH DATE'] = pd.to_datetime(filtered_data['CRASH DATE'])
#filtered_data['CRASH_DATE_DAYS_SINCE_EPOCH'] = (filtered_data['CRASH DATE'] - epoch_start).dt.days
#sorted_tcd_crashes = tcd_crashes.sort_values(by='CRASH DATE')
#plt.figure(figsize=(10, 8))
#sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=tcd_crashes, alpha=0.5, hue='CRASH_DATE_DAYS_SINCE_EPOCH', palette='RdBu')

# %%
#doing the same process as with tcd in the cell above

#checking for pedestrian/bicyclist/other pedestrian error/confusion now instead
pedConfusion_crashes = filtered_data[filtered_data['CONTRIBUTING FACTOR VEHICLE 1'].str.lower() == 'pedestrian/bicyclist/other pedestrian error/confusion']

#new data sets
improperTurn_crashes = filtered_data[filtered_data['CONTRIBUTING FACTOR VEHICLE 1'].str.lower() == 'turning improperly']

#After graphing, realized there were a few stray points that were throwing off the graph
filtered_region_forOV_crashes = filtered_data[
    (filtered_data['LATITUDE'] >= 40.7) & (filtered_data['LATITUDE'] <= 40.99) &
    (filtered_data['LONGITUDE'] >= -73.94) & (filtered_data['LONGITUDE'] <= -73.8)
]
obstructedView_crashes = filtered_region_forOV_crashes[filtered_region_forOV_crashes['CONTRIBUTING FACTOR VEHICLE 1'].str.lower() == 'view obstructed/limited']
brokenTrafficControl_crashes = filtered_data[filtered_data['CONTRIBUTING FACTOR VEHICLE 1'].str.lower() == 'traffic control device improper/non-working']
# Plot these specific crashes all on same plot

plt.figure(figsize=(10, 8))
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=pedConfusion_crashes, alpha=0.5, color = 'red')
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=improperTurn_crashes, alpha=0.5, color = 'blue')
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=tcd_crashes, alpha=0.5, color = 'green')
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=obstructedView_crashes, alpha=0.5, color = 'yellow')
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=brokenTrafficControl_crashes, alpha=0.5, color = 'black')
plt.legend(['pedestrian/bicyclist/other pedestrian error/confusion', 'turning improperly', 'traffic control disregarded', 'view obstructed/limited', 'traffic control device improper/non-working'])
plt.title('Crash Locations with Different Contributing Factors')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
#investigatory code, output hidden

#first, I want to see the dates along with the data in that specific region
streetCounting = df['ON STREET NAME'].str.lower().value_counts()
#display(streetCounting)
bronxwoodCrashes = filtered_data[df['ON STREET NAME'].str.lower() == 'bronxwood ave']
#display(bronxwoodCrashes)
laconiaCrashes = filtered_data[df['ON STREET NAME'].str.lower() == 'laconia ave']
#display(laconiaCrashes)
pauldingCrashes = filtered_data[df['ON STREET NAME'].str.lower() == 'paulding avenue']
pauldingCrashes = pd.concat([pauldingCrashes, filtered_data[df['CROSS STREET NAME'].str.lower() == 'paulding avenue']])
display(pauldingCrashes)
plt.figure(figsize=(10, 8))
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=pauldingCrashes, alpha=0.5, hue='NUMBER OF PERSONS INJURED', palette='dark')
# Out:
#        CRASH DATE   LATITUDE  LONGITUDE      ON STREET NAME CROSS STREET NAME  \
# 272    06/05/2021  40.880947 -73.854560     PAULDING AVENUE   EAST 219 STREET
# 393    06/27/2021  40.880947 -73.854560     PAULDING AVENUE   EAST 219 STREET
# 523    10/31/2021  40.890000 -73.849106     PAULDING AVENUE   EAST 232 STREET
# 1299   08/14/2022  40.867733 -73.858610     PAULDING AVENUE      ARNOW AVENUE
# 1312   08/12/2022  40.871284 -73.858500     PAULDING AVENUE      BURKE AVENUE
# ...           ...        ...        ...                 ...               ...
# 11527  07/17/2016  40.875480 -73.857580     EAST 211 STREET   PAULDING AVENUE
# 11999  05/24/2016  40.881634 -73.854126     EAST 220 STREET   PAULDING AVENUE
# 12025  05/07/2016  40.873066 -73.858440       DUNCAN STREET   PAULDING AVENUE
# 12449  05/08/2016  40.874702 -73.858030  EAST GUN HILL ROAD   PAULDING AVENUE
# 20545  09/16/2024  40.889294 -73.849495     EAST 231 STREET   PAULDING AVENUE
#
# ...

# %%
# Filter data for the specified latitude and longitude range
filtered_region_crashes = filtered_data[
    (filtered_data['LATITUDE'] >= 40.875) & (filtered_data['LATITUDE'] <= 40.9) &
    (filtered_data['LONGITUDE'] >= -73.86) & (filtered_data['LONGITUDE'] <= -73.84)
]
#display(filtered_region_crashes)
trafficRC = filtered_region_crashes[filtered_region_crashes['CONTRIBUTING FACTOR VEHICLE 1'].str.lower() == 'traffic control disregarded']
display(trafficRC)
# Plot these specific crashes
plt.figure(figsize=(10, 8))
sns.scatterplot(x='LONGITUDE', y='LATITUDE', data=trafficRC, alpha=0.5, hue='NUMBER OF PERSONS INJURED', palette='dark')
plt.title('Crash Locations within Specified Region')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()
# Out:
#        CRASH DATE   LATITUDE  LONGITUDE   ON STREET NAME  CROSS STREET NAME  \
# 161    05/17/2021  40.897625 -73.856250  EAST 237 STREET  RICHARDSON AVENUE
# 250    08/31/2022  40.899640 -73.852240  EAST 239 STREET      FURMAN AVENUE
# 272    06/05/2021  40.880947 -73.854560  PAULDING AVENUE    EAST 219 STREET
# 281    09/24/2021  40.888588 -73.849884  EAST 230 STREET    PAULDING AVENUE
# 324    04/02/2022  40.877033 -73.846375      BOSTON ROAD   EASTCHESTER ROAD
# ...           ...        ...        ...              ...                ...
# 20187  09/11/2024  40.899246 -73.846090    NEREID AVENUE  BAYCHESTER AVENUE
# 20770  01/12/2025  40.880947 -73.854550         E 219 ST       PAULDING AVE
# 20816  10/11/2024  40.876183 -73.854454   LACONIA AVENUE    EAST 213 STREET
# 20974  06/16/2025  40.895138 -73.852150       DIGNEY AVE         PITMAN AVE
# 21073  06/30/2025  40.887386 -73.853935    BRONXWOOD AVE           E 227 ST
#
# ...

# %% [markdown]
# so we realized it's actually Paulding Avenue, not bronxwood

# %%
sorted_ped_injured = filtered_data.sort_values(by='NUMBER OF PEDESTRIANS INJURED', ascending=False)
display(sorted_ped_injured.head(15))
# Out:
#        CRASH DATE   LATITUDE  LONGITUDE      ON STREET NAME  \
# 16394  10/24/2014  40.869274 -73.901344         EAMES PLACE
# 2728   10/06/2022  40.825300 -73.890686  WESTCHESTER AVENUE
# 18782  04/07/2013  40.815158 -73.917735     EAST 148 STREET
# 19772  08/26/2012  40.842846 -73.881415         VYSE AVENUE
# 2579   03/03/2024  40.849420 -73.911130       JEROME AVENUE
# 4320   11/30/2019  40.894170 -73.856964   WHITE PLAINS ROAD
# 2794   06/08/2024  40.816320 -73.896220     LONGWOOD AVENUE
# 13027  10/17/2015  40.839984 -73.877473        DEVOE AVENUE
# 20110  10/04/2024  40.820984 -73.891624     EAST 163 STREET
# 7561   07/02/2018  40.832706 -73.905060            3 AVENUE
# 20871  12/19/2024  40.819786 -73.912155            E 156 ST
# 15713  11/08/2014  40.846644 -73.904688         CLAY AVENUE
# 19700  10/14/2012  40.825578 -73.918460     EAST 161 STREET
# 18727  05/18/2013  40.863127 -73.862655         MACE AVENUE
# 10770  12/26/2016  40.872173 -73.863190     SOUTH OAK DRIVE
#
# ...

# %%
# Plotting
# Intersection column
filtered_data['ON STREET NAME'] = filtered_data['ON STREET NAME'].astype(str).str.strip().str.upper()
filtered_data['CROSS STREET NAME'] = filtered_data['CROSS STREET NAME'].astype(str).str.strip().str.upper()
filtered_data['INTERSECTION'] = filtered_data.apply(lambda row: ' & '.join(sorted([row['ON STREET NAME'], row['CROSS STREET NAME']])) if row['CROSS STREET NAME'] and row['CROSS STREET NAME'] != 'NAN' else row['ON STREET NAME'], axis=1)

# Group by intersection and sum
pedestrian_stats = filtered_data.groupby('INTERSECTION')[['NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED']].sum().reset_index()

# Sort by peds injured
top_9_peds = pedestrian_stats.sort_values(by='NUMBER OF PEDESTRIANS INJURED', ascending=False).head(9)

# Categories 'Injuries' and 'Killed'
melted_top_9 = top_9_peds.melt(id_vars=['INTERSECTION'], var_name='Metric', value_name='Count')

plt.figure(figsize=(14, 8))
sns.barplot(x='INTERSECTION', y='Count', hue='Metric', data=melted_top_9, palette='viridis')
plt.title('Top 9 Intersections by Pedestrian Injuries and Kills')
plt.xlabel('Intersection')
plt.ylabel('Number of Pedestrians')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Casualty Type')
plt.tight_layout()
plt.show()
